# %%
import numpy as np
import pandas as pd

# %%
tup=4,5,6

# %%
tup
# Out:
# (4, 5, 6)

# %%
nested_tup=(4,5,6),(7,8)

# %%
nested_tup
# Out:
# ((4, 5, 6), (7, 8))

# %%
a_lsit=[2,3,7,None]

# %%
tup=('foo','bar','baz')

# %%
b_list=list(tup)

# %%
b_list
# Out:
# ['foo', 'bar', 'baz']

# %%
b_list[1]='peekaboo'

# %%
b_list
# Out:
# ['foo', 'peekaboo', 'baz']

# %%
b_list.append('dwarf')

# %%
b_list
# Out:
# ['foo', 'peekaboo', 'baz', 'dwarf']

# %%
b_list.insert(1,'red')

# %%
b_list
# Out:
# ['foo', 'red', 'peekaboo', 'baz', 'dwarf']

# %%
b_list.pop(2)
# Out:
# 'peekaboo'

# %%
b_list
# Out:
# ['foo', 'red', 'baz', 'dwarf']

# %%
b_list.append('foo')

# %%
b_list.append('red')

# %%
b_list
# Out:
# ['foo', 'red', 'baz', 'dwarf', 'foo', 'red']

# %%
b_list.append(['baz','dwarf'])

# %%
b_list
# Out:
# ['foo', 'red', 'baz', 'dwarf', 'foo', 'red', ['baz', 'dwarf']]

# %%
b_list.remove(['baz', 'dwarf'])

# %%
b_list
# Out:
# ['foo', 'red', 'baz', 'dwarf', 'foo', 'red']

# %%
b_list.remove('foo')

# %%
b_list
# Out:
# ['red', 'baz', 'dwarf', 'foo', 'red']

# %%
a=[7,2,5,1,2]

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 2, 5, 7]

# %%
b = ['saw', 'small', 'He', 'foxes', 'six']

# %%
b.sort(key=len)

# %%
b
# Out:
# ['He', 'saw', 'six', 'small', 'foxes']

# %%
import bisect

# %%
c=[1,2,2,3,4,5,6,7]

# %%
c.insert(3,9)

# %%
c
# Out:
# [1, 2, 2, 9, 3, 4, 5, 6, 7]

# %%
c.sort()

# %%
c
# Out:
# [1, 2, 2, 3, 4, 5, 6, 7, 9]

# %%
bisect.bisect(c,6)
# Out:
# 7

# %%
bisect.insort(c,6)

# %%
c
# Out:
# [1, 2, 2, 3, 4, 5, 6, 6, 7, 9]

# %%
bisect.bisect_left(c,2)
# Out:
# 1

# %%
bisect.bisect_right(c,2)
# Out:
# 3

# %%
seq=[7,2,3,7,5,6,0,1]

# %%
seq[1:5]
# Out:
# [2, 3, 7, 5]

# %%
some_list=['foo','bar','baz']

# %%
mapping={}

# %%
for i,v in enumerate(some_list):
    mapping[v]=i

# %%
mapping
# Out:
# {'bar': 1, 'baz': 2, 'foo': 0}

# %%
empty_dict={}

# %%
d1={'a':'some value','b':[1,2,3,4]}

# %%
d1
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4]}

# %%
d1[7]='an integer'

# %%
d1
# Out:
# {7: 'an integer', 'a': 'some value', 'b': [1, 2, 3, 4]}

# %%
'b' in d1
# Out:
# True

# %%
d1[5]='some value'

# %%
d1
# Out:
# {5: 'some value', 7: 'an integer', 'a': 'some value', 'b': [1, 2, 3, 4]}

# %%
d1['dummy']='another value'

# %%
d1
# Out:
# {5: 'some value',
#  7: 'an integer',
#  'a': 'some value',
#  'b': [1, 2, 3, 4],
#  'dummy': 'another value'}

# %%
del d1[5]

# %%
d1
# Out:
# {7: 'an integer',
#  'a': 'some value',
#  'b': [1, 2, 3, 4],
#  'dummy': 'another value'}

# %%
ret=d1.pop('dummy')

# %%
ret
# Out:
# 'another value'

# %%
d1
# Out:
# {7: 'an integer', 'a': 'some value', 'b': [1, 2, 3, 4]}

# %%
list(d1.keys())
# Out:
# ['a', 'b', 7]

# %%
list(d1.values())
# Out:
# ['some value', [1, 2, 3, 4], 'an integer']

# %%
d1.update({'b':'foo','c':12})

# %%
d1
# Out:
# {7: 'an integer', 'a': 'some value', 'b': 'foo', 'c': 12}

# %%
mapping={}

# %%
for key ,value in zip(key_list,value_list):
    mapping[key]=value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-f80cec87281d> in <module>()
# ----> 1 for key ,value in zip(key_list,value_list):
#       2     mapping[key]=value
#
# NameError: name 'key_list' is not defined

# %%
string=['a','as','bce','abdecd','c','de']

# %%
for x in string:
    if x.len()>2:
        result
    result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-48e53992153a> in <module>()
#       1 for x in string:
# ----> 2     if x.len>2:
#       3         result
#       4     result
#
# AttributeError: 'str' object has no attribute 'len'
